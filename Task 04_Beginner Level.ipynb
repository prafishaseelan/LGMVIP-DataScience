# %% [markdown]
# # Image to Pencil Sketch with Python
# Task no_04
# Level: Beginner Level
# Author: Prafisha Seelan

# %%
#Importing Moduls

import cv2

# %%
image = cv2.imread("C:/Users/Dell/Downloads/Prafi.jpeg")

# %%
cv2.imshow("Prafi", image)
cv2.waitKey(0)
# Out:
# -1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.title('Original Image')
plt.axis('off')
plt.imshow(img_rgb)

# %%
gray_img=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
gray_img
# Out:
# array([[239, 239, 239, ..., 239, 239, 239],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.title('Gray scale image')
plt.axis('off')
plt.imshow(gray_img)

# %%
inverted_img=255-gray_img
plt.title('Inverted image')
plt.axis('off')
plt.imshow(inverted_img)

# %%
blurred=cv2.GaussianBlur(inverted_img, (21, 21), 0)
plt.title('Blured image')
plt.axis('off')
plt.imshow(blurred)

# %%
inverted_blurred=255-blurred
pencil_sketch=cv2.divide(gray_img, inverted_blurred, scale=256.0)
cv2.imshow("Sketch",pencil_sketch)
cv2.waitKey(0)
# Out:
# -1
